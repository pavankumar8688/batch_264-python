# %% [markdown]
# #### 1.Write a function, foo_1, that takes a NumPy array `arr` and returns the indices of the elements that are closest to a given target. If target is not in the given array, it should return ‘no item found’

# %%
import numpy as np

# %%
def foo_1(arr, target):
    if target in arr:
        x=np.abs(arr - target)
        index = np.argsort(x)
        return index
    else:
        return 'no item found'

# %%
arr = np.array([3, 8, 7, 7, 7, 7, 7, 8, 7, 10])
target = 7
foo_1(arr, target)
# Out:
# array([2, 3, 4, 5, 6, 8, 1, 7, 9, 0], dtype=int64)

# %%
arr = np.array([3, 8, 7, 7, 7, 7, 7, 8, 7, 10])
target = 11
foo_1(arr, target)
# Out:
# 'no item found'

# %% [markdown]
# #### 2.Write a user defined function foo_2 that takes a 1 or 2 dim NumPy array arr and returns a new n-1 dim array, where each element is replaced by the count of non-zero elements wrt axis.

# %%
def foo_2(arr, axis):
    if arr.ndim != 2:
        print("Input array must be 2-dimensional.")
    else:
        x=np.where(arr != 0, 1, 0)
        counts=np.sum(x,axis=axis)
        return counts

def foo_3(arr, axis):
    if arr.ndim != 3:
        print("Input array must be 3-dimensional.")
    else:
        x=np.where(arr != 0, 1, 0)
        counts=np.sum(x,axis=axis)
        return counts

# %%
arr = np.array([[1, 2, 3, 4], [0, 5, 0, 0], [2, 0, 1, 0]])
foo_2(arr, axis=0)
# Out:
# array([2, 2, 2, 1])

# %%
arr1 = np.array([[[1, 2, 3, 4], [0, 5, 0, 0], [2, 0, 1, 0]],
                 [[2, 0, 1, 0], [0, 5, 0, 0], [1, 2, 3, 4]]])

# %%
foo_3(arr1,axis=0)
# Out:
# array([[2, 1, 2, 1],
#        [0, 2, 0, 0],
#        [2, 1, 2, 1]])

# %%
foo_3(arr1,axis=1)
# Out:
# array([[2, 2, 2, 1],
#        [2, 2, 2, 1]])

# %%
foo_3(arr1,axis=2)
# Out:
# array([[4, 1, 2],
#        [2, 1, 4]])

# %% [markdown]
# #### 3.1You are given a 2D NumPy array of data representing student scores. Each row represents a student, and each column represents a subject. Extract the scores of all students who scored above 90 in at least one subject. Provide the resulting array.
# ![image.png](attachment:image.png)

# %%
second_array=np.array([[85,88,89],  
                       [78,89,94],  
                       [91,87,90],
                       [87,95,84]])

# %%
second_array
# Out:
# array([[85, 88, 89],
#        [78, 89, 94],
#        [91, 87, 90],
#        [87, 95, 84]])

# %%
def foo_2(array):
    x=np.any(second_array > 90, axis=1)
    result=array[x]                                   
    print(" students who scored greater than 90:")
    print(result)

# %%
foo_2(second_array)
# Out:
#  students who scored greater than 90:
# [[78 89 94]
#  [91 87 90]
#  [87 95 84]]

# %% [markdown]
# ### 3.2 You are provided with a 2D NumPy array of data representing sales data for different products. Each row corresponds to a product, and each column represents the monthly sales for a specific month. Calculate the following statistics for each product: mean, median, standard deviation, and the month with the highest sales.![image.png](attachment:image.png)

# %%
third_array=np.array([[120,150,130,110],
                    [200,180,220,250],
                    [90,100,95,110],     
                    [300,280,320,340]])

# %%
third_array
# Out:
# array([[120, 150, 130, 110],
#        [200, 180, 220, 250],
#        [ 90, 100,  95, 110],
#        [300, 280, 320, 340]])

# %%
product1=third_array[0,:]
product2=third_array[1,:]
product3=third_array[2,:]
product4=third_array[3,:]

# %%
print(f'The mean of product1 is : {np.mean(product1)}') 
print(f'the mean of product2 is : {np.mean(product2)}')
print(f'the mean of product3 is : {np.mean(product3)}')   
print(f'the mean of product4 is : {np.mean(product4)}')
# Out:
# The mean of product1 is : 127.5
# the mean of product2 is : 212.5
# the mean of product3 is : 98.75
# the mean of product4 is : 310.0

# %%
print(f'The median of product1 is : {np.median(product1)}')
print(f'the median of product2 is : {np.median(product2)}')
print(f'the median of product3 is : {np.median(product3)}')
print(f'the median of product4 is : {np.median(product4)}')
# Out:
# The median of product1 is : 125.0
# the median of product2 is : 210.0
# the median of product3 is : 97.5
# the median of product4 is : 310.0

# %%
print(f'The standard_deviation of product1 is : {np.std(product1)}')
print(f'the standard_deviation of product2 is : {np.std(product2)}')
print(f'the standard_deviation of product3 is : {np.std(product3)}')
print(f'the standard_deviation of product4 is : {np.std(product4)}')
# Out:
# The standard_deviation of product1 is : 14.79019945774904
# the standard_deviation of product2 is : 25.8602010819715
# the standard_deviation of product3 is : 7.39509972887452
# the standard_deviation of product4 is : 22.360679774997898

# %%
fst_mnth=third_array[:,0]
scnd_mnth=third_array[:,1]
thrd_mnth=third_array[:,2]
frth_mnth=third_array[:,3]

# %%
print(f'first month of sales : {np.sum(fst_mnth)}')
print(f'second month of sales : {np.sum(scnd_mnth)}')
print(f'third month of sales  : {np.sum(thrd_mnth)}')
print(f'fourth month of sales : {np.sum(frth_mnth)}')
# Out:
# first month of sales : 710
# second month of sales : 710
# third month of sales  : 765
# fourth month of sales : 810

# %% [markdown]
# #### 3.3 Create a NumPy array of size 1000 with random integers between 1 and 100. Then, use NumPy functions to find the top 10 most frequently occurring values in the array.

# %%
random_array = np.random.randint(1, 101, size=1000)
print(random_array)

unique_values, counts = np.unique(random_array, return_counts=1)

sorted_indices = np.argsort(counts)[::-1]

top_values = unique_values[sorted_indices[:10]]
top_counts = counts[sorted_indices[:10]]

print("Top 10 most frequently occurring values:")
for value, count in zip(top_values, top_counts):
    print(f"{value}: {count} occurrences")
# Out:
# [ 58  97  46  32  24   1  78  13  92  51  23  76  67  66  91  32  93  16
#   24   5  57  51  36  36  20  35  82  40  36  52  73  73  89  87  38  74
#   19  66  11  26  80   3  43   9  74   1  11  39  18  86  14  26  85  89
#   61  97   7  90  64  54   9  49  54  86   3  90  85  61  16  94  71  37
#   93  85  20  46  41  66  30  55  26  28  27  95  58  14  80  37   8  31
#   98  76  89  97  46  32  13  73  74  29  22  71  21  31  11  25  87  33
#   81  87  78  42  90  94   1  98  22  97  10  80  85  83  30  33  13  66
#   63  58  20  83  98   8  96  60  11  58  39  24  17  69  63  70  55  30
#    5  52  52  12  60  86  19  71   6  84  55 100  29  86  22  73  58  59
#   43  73  89  67  82  40  20  69  20  99  78  39   7  57  65  37  79  45
#   47   1  11   2  86  28  61  53  43  29  35   7  63  10  47  45  26  77
#    3  57  16  21  70  52  89  50  31  99  54  46  57  70  51  70  48   6
#   37  95  84  42  73  39  31  29  17  81  56  53  82  24  63  65   8  58
#   21  52   9  14  50  36  36   7  74  55  16  23  57  44   2  52  23  65
#   73  89  75  46   1  14  47  62  92  98  40  28  13  19  71  10  19  30
#    3  35  99  92  76  38   9  18  68  46  64  52  71  86  20  74  86  57
